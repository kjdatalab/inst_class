# %%
import librosa
import soundfile as sf
import os
import numpy as np
import string
import pandas as pd

# %%
def segment_audio(input_file, output_folder, segment_length_sec=5):
    #Load audio files
    audio, sr = librosa.load(input_file, sr=None) #Keeps original sample rate

    # Calculate total length of the audio
    segment_length_samples = segment_length_sec * sr

    # Calculate number of full segments
    num_segments = len(audio) // segment_length_samples
    clips = []

    # Extract full 5-sec clips
    for i in range(num_segments):
        start_sample = i * segment_length_samples
        end_sample = start_sample + segment_length_samples
        clip = audio[start_sample:end_sample]
        clips.append(clip)

    # Handle the last segment (if shorter than 5 secs)
    if len(audio) % segment_length_samples != 0:
        last_clip = audio[num_segments * segment_length_samples:]
        # Pad the last clip with silence if less than 5 secs
        silence_duration_samples = segment_length_samples - len(last_clip)
        silence = np.zeros(silence_duration_samples)
        last_clip = np.concatenate([last_clip, silence])
        clips.append(last_clip)

    # Save clips to output directory
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    # Get base name of input file (without extension)
    base_filename = os.path.splitext(os.path.basename(input_file))[0]

    # Generate file names(a, b, c, ..., z, aa, ab, ...)
    alphabet = list(string.ascii_lowercase)

    for idx, clip in enumerate(clips):
        # Generate segment filename (e.g., "original_filename_a.wav", "original_filename_b.wav")
        clip_name = f"{base_filename}_{alphabet[idx % 26]}.wav"

        # For indices larger than 25 (after 'z'), start using double letters
        if idx >= 26:
            clip_name = f"{base_filename}_{alphabet[(idx // 26) - 1]}{alphabet[idx % 26]}.wav"

        # Save audio clip using soundfile
        output_file = os.path.join(output_folder, clip_name)
        sf.write(output_file, clip, sr)  # Write the audio clip
        print(f"Saved: {output_file}")

# Usage
input_folder = os.path.join("Data", "musicnet", "musicnet", "train_data")  # Relative path to input folder
output_folder = os.path.join("Data", "musicnet", "musicnet", "all_train_data_5_seconds")  # Output folder path

# Get all .wav files in input folder
input_files = [os.path.join(input_folder, filename) for filename in os.listdir(input_folder) if filename.endswith('.wav')]

# Process each file
for input_file in input_files:
    segment_audio(input_file, output_folder)
# Out:
# Saved: Data/musicnet/musicnet/all_train_data_5_seconds/2611_a.wav
# Saved: Data/musicnet/musicnet/all_train_data_5_seconds/2611_b.wav
# Saved: Data/musicnet/musicnet/all_train_data_5_seconds/2611_c.wav
# Saved: Data/musicnet/musicnet/all_train_data_5_seconds/2611_d.wav
# Saved: Data/musicnet/musicnet/all_train_data_5_seconds/2611_e.wav
# Saved: Data/musicnet/musicnet/all_train_data_5_seconds/2611_f.wav
# Saved: Data/musicnet/musicnet/all_train_data_5_seconds/2611_g.wav
# Saved: Data/musicnet/musicnet/all_train_data_5_seconds/2611_h.wav
# Saved: Data/musicnet/musicnet/all_train_data_5_seconds/2611_i.wav
# Saved: Data/musicnet/musicnet/all_train_data_5_seconds/2611_j.wav
# Saved: Data/musicnet/musicnet/all_train_data_5_seconds/2611_k.wav
# Saved: Data/musicnet/musicnet/all_train_data_5_seconds/2611_l.wav
# Saved: Data/musicnet/musicnet/all_train_data_5_seconds/2611_m.wav
# Saved: Data/musicnet/musicnet/all_train_data_5_seconds/2611_n.wav
# Saved: Data/musicnet/musicnet/all_train_data_5_seconds/2611_o.wav
# Saved: Data/musicnet/musicnet/all_train_data_5_seconds/2611_p.wav
# Saved: Data/musicnet/musicnet/all_train_data_5_seconds/2611_q.wav
# Saved: Data/musicnet/musicnet/all_train_data_5_seconds/2611_r.wav
# Saved: Data/musicnet/musicnet/all_train_data_5_seconds/2611_s.wav
# Saved: Data/musicnet/musicnet/all_train_data_5_seconds/2611_t.wav
# Saved: Data/musicnet/musicnet/all_train_data_5_seconds/2611_u.wav
# Saved: Data/musicnet/musicnet/all_train_data_5_seconds/2611_v.wav
# Saved: Data/musicnet/musicnet/all_train_data_5_seconds/2611_w.wav
# Saved: Data/musicnet/musicnet/all_train_data_5_seconds/2611_x.wav
# Saved: Data/musicnet/musicnet/all_train_data_5_seconds/2611_y.wav
# Saved: Data/musicnet/musicnet/all_train_data_5_seconds/2611_z.wav
# Saved: Data/musicnet/musicnet/all_train_data_5_seconds/2611_aa.wav
# Saved: Data/musicnet/musicnet/all_train_data_5_seconds/2611_ab.wav
# Saved: Data/musicnet/musicnet/all_train_data_5_seconds/2611_ac.wav
# Saved: Data/musicnet/musicnet/all_train_data_5_seconds/2611_ad.wav
# Saved: Data/musicnet/musicnet/all_train_data_5_seconds/2611_ae.wav
# Saved: Data/musicnet/musicnet/all_train_data_5_seconds/2611_af.wav
# Saved: Data/musicnet/musicnet/all_train_data_5_seconds/2611_ag.wav
# Saved: Data/musicnet/musicnet/all_train_data_5_seconds/2611_ah.wav
# Saved: Data/musicnet/musicnet/all_train_data_5_seconds/2611_ai.wav
# Saved: Data/musicnet/musicnet/all_train_data_5_seconds/2611_aj.wav
# Saved: Data/musicnet/musicnet/all_train_data_5_seconds/2611_ak.wav
# Saved: Data/musicnet/musicnet/all_train_data_5_seconds/2611_al.wav
# Saved: Data/musicnet/musicnet/all_train_data_5_seconds/2611_am.wav
# Saved: Data/musicnet/musicnet/all_train_data_5_seconds/2611_an.wav
# Saved: Data/musicnet/musicnet/all_train_data_5_seconds/2611_ao.wav
# Saved: Data/musicnet/musicnet/all_train_data_5_seconds/2611_ap.wav
# Saved: Data/musicnet/musicnet/all_train_data_5_seconds/2611_aq.wav
# Saved: Data/musicnet/musicnet/all_train_data_5_seconds/2611_ar.wav
# Saved: Data/musicnet/musicnet/all_train_data_5_seconds/2611_as.wav
# Saved: Data/musicnet/musicnet/all_train_data_5_seconds/2611_at.wav
# Saved: Data/musicnet/musicnet/all_train_data_5_seconds/2611_au.wav
# Saved: Data/musicnet/musicnet/all_train_data_5_seconds/2611_av.wav
# Saved: Data/musicnet/musicnet/all_train_data_5_seconds/2611_aw.wav
# Saved: Data/musicnet/musicnet/all_train_data_5_seconds/2611_ax.wav
# Saved: Data/musicnet/musicnet/all_train_data_5_seconds/2611_ay.wav
# Saved: Data/musicnet/musicnet/all_train_data_5_seconds/2611_az.wav
# Saved: Data/musicnet/musicnet/all_train_data_5_seconds/2611_ba.wav
# Saved: Data/musicnet/musicnet/all_train_data_5_seconds/2611_bb.wav
# Saved: Data/musicnet/musicnet/all_train_data_5_seconds/2611_bc.wav
# Saved: Data/musicnet/musicnet/all_train_data_5_seconds/2611_bd.wav
# Saved: Data/musicnet/musicnet/all_train_data_5_seconds/2611_be.wav
# Saved: Data/musicnet/musicnet/all_train_data_5_seconds/2611_bf.wav
# Saved: Data/musicnet/musicnet/all_train_data_5_seconds/2611_bg.wav
# Saved: Data/musicnet/musicnet/all_train_data_5_seconds/2611_bh.wav
# Saved: Data/musicnet/musicnet/all_train_data_5_seconds/2611_bi.wav
# Saved: Data/musicnet/musicnet/all_train_data_5_seconds/2611_bj.wav
# Saved: Data/musicnet/musicnet/all_train_data_5_seconds/2611_bk.wav
# Saved: Data/musicnet/musicnet/all_train_data_5_seconds/2611_bl.wav
# Saved: Data/musicnet/musicnet/all_train_data_5_seconds/2611_bm.wav
# Saved: Data/musicnet/musicnet/all_train_data_5_seconds/2611_bn.wav
# Saved: Data/musicnet/musicnet/all_train_data_5_seconds/2611_bo.wav
# Saved: Data/musicnet/musicnet/all_train_data_5_seconds/2611_bp.wav
# Saved: Data/musicnet/musicnet/all_train_data_5_seconds/2611_bq.wav
# Saved: Data/musicnet/musicnet/all_train_data_5_seconds/2611_br.wav
# Saved: Data/musicnet/musicnet/all_train_data_5_seconds/2611_bs.wav
# Saved: Data/musicnet/musicnet/all_train_data_5_seconds/2611_bt.wav
# Saved: Data/musicnet/musicnet/all_train_data_5_seconds/2611_bu.wav
# Saved: Data/musicnet/musicnet/all_train_data_5_seconds/2611_bv.wav
# Saved: Data/musicnet/musicnet/all_train_data_5_seconds/2611_bw.wav
# Saved: Data/musicnet/musicnet/all_train_data_5_seconds/2611_bx.wav
# Saved: Data/musicnet/musicnet/all_train_data_5_seconds/2611_by.wav
# Saved: Data/musicnet/musicnet/all_train_data_5_seconds/2611_bz.wav
# Saved: Data/musicnet/musicnet/all_train_data_5_seconds/2611_ca.wav
# Saved: Data/musicnet/musicnet/all_train_data_5_seconds/2611_cb.wav
# Saved: Data/musicnet/musicnet/all_train_data_5_seconds/2611_cc.wav
# Saved: Data/musicnet/musicnet/all_train_data_5_seconds/2611_cd.wav
# Saved: Data/musicnet/musicnet/all_train_data_5_seconds/2611_ce.wav
# Saved: Data/musicnet/musicnet/all_train_data_5_seconds/2611_cf.wav
# Saved: Data/musicnet/musicnet/all_train_data_5_seconds/2611_cg.wav
# Saved: Data/musicnet/musicnet/all_train_data_5_seconds/2611_ch.wav
# Saved: Data/musicnet/musicnet/all_train_data_5_seconds/2611_ci.wav
# Saved: Data/musicnet/musicnet/all_train_data_5_seconds/2611_cj.wav
# Saved: Data/musicnet/musicnet/all_train_data_5_seconds/2611_ck.wav
# Saved: Data/musicnet/musicnet/all_train_data_5_seconds/2611_cl.wav
# Saved: Data/musicnet/musicnet/all_train_data_5_seconds/2611_cm.wav
# Saved: Data/musicnet/musicnet/all_train_data_5_seconds/2611_cn.wav
# Saved: Data/musicnet/musicnet/all_train_data_5_seconds/2611_co.wav
# Saved: Data/musicnet/musicnet/all_train_data_5_seconds/2611