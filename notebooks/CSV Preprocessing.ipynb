# %% [markdown]
# # CSV Preprocessing

# %%
import pandas as pd
import os
import numpy as np
import math

# %% [markdown]
# ## Imports

# %% [markdown]
# ### Creata data frame from the raw csv

# %%
def df_from_csv(path):

    ''''
    Creates a new data frame from the original csv, containing the following columns: "instrument",
    "start_time_in_seconds" and "end_time_in_seconds".

    '''

    df = pd.read_csv(path) # adjust the path

    sample_rate = 44100

    df['start_time_in_seconds'] = df['start_time'] / sample_rate
    df['end_time_in_seconds'] = df['end_time'] / sample_rate

    df = df.drop(columns=['start_time','end_time','note', 'start_beat', 'end_beat','note_value'])


    return df

# %%
def reduce_csvs(df):

    seconds_limit = 30  # Change depending on the need

    # Filter rows based on seconds limit
    df_reduced = df[df['end_time_in_seconds'] <= seconds_limit].drop_duplicates()

    return df_reduced

# %% [markdown]
# ### Creata data frame from the raw csv

# %%
def create_csvs():
    '''
    Creates new CSVs.
    '''
    csv_dir = 'train_labels'  # Directory containing the CSV files
    output_dir = 'csv_data/preprocessed_csv_data'  # Directory to save the reduced files
    os.makedirs(output_dir, exist_ok=True)  # Create the output directory if it doesn't exist

    # Iterate over all CSV files in the directory
    for file in os.listdir(csv_dir):
        if file.endswith('.csv'):  # Process only CSV files
            path = os.path.join(csv_dir, file)

            try:
                df = pd.read_csv(path)
            except Exception as e:
                print(f"Error reading {file}: {e}")
                continue

            df = df_from_csv(path)

            # Filter rows based on seconds limit
            #df = reduce_csvs(df)

            new_file = os.path.join(output_dir, f'new_{file}')
            df.to_csv(new_file, index=False)
            print(f"New file saved to: {new_file}")

# %%
create_csvs()
# Out:
# New file saved to: csv_data/preprocessed_csv_data/new_2282.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2296.csv
# New file saved to: csv_data/preprocessed_csv_data/new_1760.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2527.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2241.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2533.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2080.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2490.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2335.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2320.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2334.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2308.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2491.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2678.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2081.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2532.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2240.csv
# New file saved to: csv_data/preprocessed_csv_data/new_1749.csv
# New file saved to: csv_data/preprocessed_csv_data/new_1775.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2297.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2283.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2295.csv
# New file saved to: csv_data/preprocessed_csv_data/new_1788.csv
# New file saved to: csv_data/preprocessed_csv_data/new_1763.csv
# New file saved to: csv_data/preprocessed_csv_data/new_1777.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2530.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2242.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2083.csv
# New file saved to: csv_data/preprocessed_csv_data/new_1818.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2487.csv
# New file saved to: csv_data/preprocessed_csv_data/new_1824.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2478.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2444.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2322.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2336.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2451.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2492.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2486.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2082.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2243.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2531.csv
# New file saved to: csv_data/preprocessed_csv_data/new_1776.csv
# New file saved to: csv_data/preprocessed_csv_data/new_1789.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2294.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2284.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2521.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2247.csv
# New file saved to: csv_data/preprocessed_csv_data/new_1766.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2509.csv
# New file saved to: csv_data/preprocessed_csv_data/new_1772.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2079.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2131.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2119.csv
# New file saved to: csv_data/preprocessed_csv_data/new_1835.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2482.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2441.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2497.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2483.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2118.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2078.csv
# New file saved to: csv_data/preprocessed_csv_data/new_1773.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2285.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2293.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2244.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2522.csv
# New file saved to: csv_data/preprocessed_csv_data/new_1771.csv
# New file saved to: csv_data/preprocessed_csv_data/new_1765.csv
# New file saved to: csv_data/preprocessed_csv_data/new_1822.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2481.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2330.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2442.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2318.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2319.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2443.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2325.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2480.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2494.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2127.csv
# New file saved to: csv_data/preprocessed_csv_data/new_1764.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2537.csv
# New file saved to: csv_data/preprocessed_csv_data/new_1758.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2523.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2292.csv
# New file saved to: csv_data/preprocessed_csv_data/new_1918.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2593.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2222.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2550.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2168.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2632.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2154.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2140.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2626.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2381.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2424.csv
# New file saved to: csv_data/preprocessed_csv_data/new_1893.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2342.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2343.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2357.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2431.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2627.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2633.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2155.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2169.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2196.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2237.csv
# New file saved to: csv_data/preprocessed_csv_data/new_1931.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2586.csv
# New file saved to: csv_data/preprocessed_csv_data/new_1919.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2590.csv
# New file saved to: csv_data/preprocessed_csv_data/new_1933.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2209.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2221.csv
# New file saved to: csv_data/preprocessed_csv_data/new_1728.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2180.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2194.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2619.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2157.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2341.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2433.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2432.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2368.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2397.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2383.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2156.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2618.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2195.csv
# New file saved to: csv_data/preprocessed_csv_data/new_1729.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2220.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2234.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2208.csv
# New file saved to: csv_data/preprocessed_csv_data/new_1932.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2591.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2595.csv
# New file saved to: csv_data/preprocessed_csv_data/new_1922.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2581.csv
# New file saved to: csv_data/preprocessed_csv_data/new_1739.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2230.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2224.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2542.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2218.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2620.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2608.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2393.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2422.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2350.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2436.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2379.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2423.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2345.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2392.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2147.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2621.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2219.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2225.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2557.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2231.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2594.csv
# New file saved to: csv_data/preprocessed_csv_data/new_1923.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2582.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2596.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2227.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2555.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2186.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2151.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2179.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2390.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2384.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2346.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2420.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2391.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2178.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2622.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2150.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2568.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2232.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2540.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2203.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2571.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2217.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2149.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2161.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2607.csv
# New file saved to: csv_data/preprocessed_csv_data/new_1859.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2388.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2377.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2411.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2405.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2404.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2376.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2410.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2389.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2160.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2148.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2570.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2202.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2564.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2228.csv
# New file saved to: csv_data/preprocessed_csv_data/new_1735.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2214.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2572.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2566.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2200.csv
# New file saved to: csv_data/preprocessed_csv_data/new_1872.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2348.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2406.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2374.csv
# New file saved to: csv_data/preprocessed_csv_data/new_1873.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2177.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2611.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2567.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2201.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2215.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2573.csv
# New file saved to: csv_data/preprocessed_csv_data/new_1734.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2229.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2588.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2211.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2239.csv
# New file saved to: csv_data/preprocessed_csv_data/new_1730.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2198.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2167.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2629.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2403.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2365.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2371.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2417.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2359.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2358.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2364.csv
# New file saved to: csv_data/preprocessed_csv_data/new_1876.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2614.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2166.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2238.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2204.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2562.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2576.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2210.csv
# New file saved to: csv_data/preprocessed_csv_data/new_1916.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2560.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2212.csv
# New file saved to: csv_data/preprocessed_csv_data/new_1733.csv
# New file saved to: csv_data/preprocessed_csv_data/new_1727.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2158.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2372.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2366.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2415.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2373.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2398.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2159.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2603.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2213.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2575.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2207.csv
# New file saved to: csv_data/preprocessed_csv_data/new_1755.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2248.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2506.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2512.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2076.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2116.csv
# New file saved to: csv_data/preprocessed_csv_data/new_1812.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2472.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2314.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2300.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2466.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2473.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2315.csv
# New file saved to: csv_data/preprocessed_csv_data/new_1813.csv
# New file saved to: csv_data/preprocessed_csv_data/new_1807.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2117.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2659.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2077.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2507.csv
# New file saved to: csv_data/preprocessed_csv_data/new_1768.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2288.csv
# New file saved to: csv_data/preprocessed_csv_data/new_1742.csv
# New file saved to: csv_data/preprocessed_csv_data/new_1756.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2505.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2075.csv
# New file saved to: csv_data/preprocessed_csv_data/new_1811.csv
# New file saved to: csv_data/preprocessed_csv_data/new_1805.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2471.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2302.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2114.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2504.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2510.csv
# New file saved to: csv_data/preprocessed_csv_data/new_1757.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2538.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2289.csv
# New file saved to: csv_data/preprocessed_csv_data/new_1790.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2514.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2528.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2104.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2138.csv
# New file saved to: csv_data/preprocessed_csv_data/new_1828.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2313.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2307.csv
# New file saved to: csv_data/preprocessed_csv_data/new_1829.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2677.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2105.csv
# New file saved to: csv_data/preprocessed_csv_data/new_1752.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2529.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2501.csv
# New file saved to: csv_data/preprocessed_csv_data/new_1791.csv
# New file saved to: csv_data/preprocessed_csv_data/new_1793.csv
# New file saved to: csv_data/preprocessed_csv_data/new_1750.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2113.csv
# New file saved to: csv_data/preprocessed_csv_data/new_1817.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2488.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2477.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2463.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2305.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2462.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2304.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2310.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2476.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2112.csv
# New file saved to: csv_data/preprocessed_csv_data/new_1751.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2516.csv
# New file saved to: csv_data/preprocessed_csv_data/new_2502.csv
# New file saved to: csv_data/preprocessed_csv_data/new_1792.csv

# %%
def process_and_combine_csvs():

    instrument_dict = {
        1: "Piano",
        41: "Violin",
        42: "Viola",
        43: "Cello",
        61: "Horn",
        71: "Bassoon",
        72: "Clarinet",
    }

    input_dir = 'csv_data/preprocessed_csv_data'
    combined_rows = []  # List to store all rows for final DataFrame

    for file in os.listdir(input_dir):
        if file.endswith(".csv"):  # Check for CSV files
            input_csv = os.path.join(input_dir, file)

            df = pd.read_csv(input_csv)

            if 'start_time_in_seconds' not in df.columns or 'end_time_in_seconds' not in df.columns or 'instrument' not in df.columns:
                print(f"Error: Missing expected columns in {file}. Skipping this file.")
                continue

            file_start_time = df['start_time_in_seconds'].min()
            file_end_time = df['end_time_in_seconds'].max()
            instruments = df['instrument'].unique()

            target = list(instruments)
            category = [instrument_dict[i] for i in target if i in instrument_dict]

            audio_file_name = file.replace('new_', '').replace('.csv', '.wav')

            combined_rows.append({
                "start_time": file_start_time,
                "end_time": file_end_time,
                "filename": f"./train_data/{audio_file_name}",
                "target": target,
                "category": category,
            })

    combined_df = pd.DataFrame(combined_rows)

    if combined_df.empty:
        print("No valid rows were processed. Please check the input files.")
        return

    output_file = 'csv_data/preprocessed_csv_data/preprocessed_data.csv'
    combined_df.to_csv(output_file, index=False)
    print(f"Preprocessed CSV saved to: {output_file}")

# %%
process_and_combine_csvs()
# Out:
# Error: Missing expected columns in preprocessed_data_sliced.csv. Skipping this file.
# Preprocessed CSV saved to: csv_data/preprocessed_csv_data/preprocessed_data.csv

# %%
def process_and_combine_csvs_sliced():

    instrument_dict = {
        1: "Piano",
        41: "Violin",
        42: "Viola",
        43: "Cello",
        61: "Horn",
        71: "Bassoon",
        72: "Clarinet",
    }


    input_dir = 'csv_data/preprocessed_csv_data' #change the path, if needed
    frame_length = 5  # Length of each frame in seconds

    combined_rows = []

    for file in os.listdir(input_dir):
        if file.endswith(".csv"):
            input_csv = os.path.join(input_dir, file)

            df = pd.read_csv(input_csv)

            if 'start_time_in_seconds' not in df.columns or 'end_time_in_seconds' not in df.columns:
                print(f"Error: Missing expected columns in {file}. Skipping this file.")
                continue

            # Calculate the total duration of the audio based on the CSV's time range
            max_time = df[["end_time_in_seconds"]].max().values[0]
            min_time = df[["start_time_in_seconds"]].min().values[0]
            num_frames = int(np.ceil(max_time / frame_length))  # Total number of frames

            instruments = df['instrument'].unique()

            # Resolve instrument details
            target = list(instruments)
            category = [instrument_dict[i] for i in target if i in instrument_dict]

            frame_data = {"frame_index": range(num_frames)}
            frame_df = pd.DataFrame(frame_data)
            frame_df["start_time"] = frame_df["frame_index"] * frame_length
            frame_df["end_time"] = (frame_df["frame_index"] + 1) * frame_length


            def index_to_suffix(index):
                suffix = ""
                while index >= 0:
                    suffix = chr(97 + (index % 26)) + suffix  # ASCII 'a' is 97
                    index = (index // 26) - 1
                return suffix

            for frame_idx, frame in frame_df.iterrows():
                interval_start = frame['start_time']
                interval_end = frame['end_time']

                instruments_in_frame = df[
                    (df['start_time_in_seconds'] < interval_end) &
                    (df['end_time_in_seconds'] > interval_start)
                    ]['instrument'].unique()

                target = list(instruments_in_frame)
                category = [instrument_dict[i] for i in target if i in instrument_dict]

                audio_file_base_name = file.replace('new_', '').replace('.csv', '')
                suffix = index_to_suffix(frame_idx)  # Convert frame index to suffix

                # Construct the final filename
                audio_file_name = f"sliced_audio/{audio_file_base_name}_{suffix}.wav"

                # Append the processed row to the combined list
                combined_rows.append({
                    "start_time": interval_start,
                    "end_time": interval_end,
                    "filename": audio_file_name,
                    "target": target,
                    "category": category,
                })

    combined_df = pd.DataFrame(combined_rows)

    output_file = 'csv_data/preprocessed_csv_data/preprocessed_data_sliced.csv'


    combined_df.to_csv(output_file, index=False)
    print(f"Preprocessed CSV saved to: {output_file}")

# %%
process_and_combine_csvs_sliced()
# Out:
# Error: Missing expected columns in preprocessed_data.csv. Skipping this file.
# Error: Missing expected columns in preprocessed_data_sliced.csv. Skipping this file.
# Preprocessed CSV saved to: csv_data/preprocessed_csv_data/preprocessed_data_sliced.csv
